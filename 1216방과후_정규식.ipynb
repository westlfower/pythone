# %% [markdown]
# <a href="https://colab.research.google.com/github/westlfower/pythone/blob/main/1216%EB%B0%A9%EA%B3%BC%ED%9B%84_%EC%A0%95%EA%B7%9C%EC%8B%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 각 줄 시작에만 이메일이 있는지 검사 (MULTILINE 사용)
line_emails = re.compile(r'^[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b', re.MULTILINE)
result = line_emails.findall(email_text)
print(result)  # [] (테스트 데이터에서 줄 시작에 이메일 없음)

# 줄 시작에 이메일이 있는 데이터로 테스트
start_email_text = """user@example.com 안녕하세요
support@naver.com 문의주세요"""
print(line_emails.findall(start_email_text))  # ['user@example.com', 'support@naver.com']
