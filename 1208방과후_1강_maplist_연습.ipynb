# %% [markdown]
# <a href="https://colab.research.google.com/github/westlfower/pythone/blob/main/1208%EB%B0%A9%EA%B3%BC%ED%9B%84_1%EA%B0%95_maplist_%EC%97%B0%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
점수=[10,9,7,10,9,8,7,6,4,7,3,7,10,5]

# %%
#리스갯수 세기 len(점수) 직접구현
i=0
for x in 점수:
  i=i+1
print(i)
# Out:
# 14

# %%
len(점수)
# Out:
# 14

# %%
#점수의 평균 구하기
m=0
s=0
for x in 점수:
  s=s+x
m=s/len(점수)

# %%
m
# Out:
# 7.285714285714286

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-482841644.py in <cell line: 0>()
# ----> 1 sum(점수)
#
# TypeError: 'int' object is not callable

# %%
점수
# Out:
# [10, 9, 7, 10, 9, 8, 7, 6, 4, 7, 3, 7, 10, 5]

# %%
sum(점수)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-482841644.py in <cell line: 0>()
# ----> 1 sum(점수)
#
# TypeError: 'int' object is not callable

# %%
#
점수의제곱=[]
for x in 점수:
  점수의제곱.append(x*x)

# %%
점수의제곱
# Out:
# [100, 81, 49, 100, 81, 64, 49, 36, 16, 49, 9, 49, 100, 25]

# %%
def 제곱(x):
  return x*x
y=list(map(제곱,점수))

# %%
y
# Out:
# [100, 81, 49, 100, 81, 64, 49, 36, 16, 49, 9, 49, 100, 25]
